# %% [markdown]
# ## Cluster zip codes using k-means

# %%
# clustering
from sklearn.cluster import KMeans
import pandas as pd
from typing import List
import numpy as np

# %% [markdown]
# ### Filter data

# %%
def new_filter_signal(data_path: str, signal_strength: List):
    df = pd.read_csv(data_path, usecols=['zipcode', 'callsign', 'signal_strength'], dtype={'zipcode': str})
    # For test
    #df = df.sample(1000, random_state=10)
    cdf = df.groupby(['zipcode', 'callsign'], dropna=False).agg({'signal_strength': min}).unstack(fill_value=0).reset_index()
    cdf.columns = ['zipcode'] + cdf.columns.get_level_values(1).tolist()[1:]
    del cdf[np.nan]
    to_replace = {}
    for ss in [1, 2, 3, 4]:
        to_replace[ss] = 1 if ss in signal_strength else 0
    cdf.replace(to_replace, inplace=True)
    return cdf.set_index('zipcode')

# %%
data_path = "./stations.csv"
signal_strength = [1, 2]

df = new_filter_signal(data_path, signal_strength)

# %%
df.head(10)
# Out:
#          K04QP-D  K09YZ-D  K10OG-D  K17ED-D  K17GD-D  K17JI-D  K19GH-D  \
# zipcode
# 00501          0        0        0        0        0        0        0
# 00544          0        0        0        0        0        0        0
# 00601          0        0        0        0        0        0        0
# 00602          0        0        0        0        0        0        0
# 00603          0        0        0        0        0        0        0
# 00606          0        0        0        0        0        0        0
# 00610          0        0        0        0        0        0        0
# 00612          0        0        0        0        0        0        0
# 00616          0        0        0        0        0        0        0
# 00617          0        0        0        0        0        0        0
#
#          K20DN-D  K20JX-D  K21DO-D  ...  WZDX  WZMQ  WZPX-TV  WZRA-CD  WZRB  \
# zipcode                             ...
# 00501          0        0        0  ...     0     0        0        0     0
# 00544          0        0        0  ...     0     0        0        0     0
# 00601          0        0        0  ...     0     0        0        0     0
# 00602          0        0        0  ...     0     0        0        0     0
# 00603          0        0        0  ...     0     0        0        0     0
# 00606          0        0        0  ...     0     0        0        0     0
# 00610          0        0        0  ...     0     0        0        0     0
# 00612          0        0        0  ...     0     0        0        0     0
# 00616          0        0        0  ...     0     0        0        0     0
# 00617          0        0        0  ...     0     0        0        0     0
#
#          WZTV  WZVI  WZVN-TV  WZXZ-CD  WZZM
# zipcode
# 00501       0     0        0        0     0
# 00544       0     0        0        0     0
# 00601       0     0        0        0     0
# 00602       0     0        0        0     0
# 00603       0     0        0        0     0
# 00606       0     0        0        0     0
# 00610       0     0        0        0     0
# 00612       0     0        0        0     0
# 00616       0     0        0        0     0
# 00617       0     0        0        0     0
#
# [10 rows x 2027 columns]

# %%
print(df.shape)
# Take out rows with all zeroes
df = df.loc[(df.sum(axis=1) != 0)]
print(df.shape)
# Out:
# (36094, 2027)
# (33790, 2027)

# %%
model = KMeans(n_clusters=200)
X= df.iloc[:,:-1].values
model.fit(X)
yhat = model.predict(X)

# %%
df['k_means_cluster'] = pd.Series(yhat, index=df.index)
df['zipcode'] = df.index

# %%
df.head(10)
# Out:
#          K04QP-D  K09YZ-D  K10OG-D  K17ED-D  K17GD-D  K17JI-D  K19GH-D  \
# zipcode
# 00501          0        0        0        0        0        0        0
# 00544          0        0        0        0        0        0        0
# 00601          0        0        0        0        0        0        0
# 00602          0        0        0        0        0        0        0
# 00603          0        0        0        0        0        0        0
# 00606          0        0        0        0        0        0        0
# 00610          0        0        0        0        0        0        0
# 00612          0        0        0        0        0        0        0
# 00616          0        0        0        0        0        0        0
# 00617          0        0        0        0        0        0        0
#
#          K20DN-D  K20JX-D  K21DO-D  ...  WZPX-TV  WZRA-CD  WZRB  WZTV  WZVI  \
# zipcode                             ...
# 00501          0        0        0  ...        0        0     0     0     0
# 00544          0        0        0  ...        0        0     0     0     0
# 00601          0        0        0  ...        0        0     0     0     0
# 00602          0        0        0  ...        0        0     0     0     0
# 00603          0        0        0  ...        0        0     0     0     0
# 00606          0        0        0  ...        0        0     0     0     0
# 00610          0        0        0  ...        0        0     0     0     0
# 00612          0        0        0  ...        0        0     0     0     0
# 00616          0        0        0  ...        0        0     0     0     0
# 00617          0        0        0  ...        0        0     0     0     0
#
#          WZVN-TV  WZXZ-CD  WZZM  k_means_cluster  zipcode
# zipcode
# 00501          0        0     0              134    00501
# 00544          0        0     0              134    00544
# 00601          0        0     0                1    00601
# 00602          0        0     0                1    00602
# 00603          0        0     0                1    00603
# 00606          0        0     0                1    00606
# 00610          0        0     0                1    00610
# 00612          0        0     0               65    00612
# 00616          0        0     0                1    00616
# 00617          0        0     0               65    00617
#
# [10 rows x 2029 columns]

# %%
df["zipcode"] = df["zipcode"].astype(str)

# %%
# saving to CSV was causing zipcode to come back up as numeric
df.to_pickle("k_means_200.pkl", compression = "xz")

# %%
pd.read_pickle("k_means_200.pkl", compression = "xz").head()
# Out:
#          K04QP-D  K09YZ-D  K10OG-D  K17ED-D  K17GD-D  K17JI-D  K19GH-D  \
# zipcode
# 00501          0        0        0        0        0        0        0
# 00544          0        0        0        0        0        0        0
# 00601          0        0        0        0        0        0        0
# 00602          0        0        0        0        0        0        0
# 00603          0        0        0        0        0        0        0
#
#          K20DN-D  K20JX-D  K21DO-D  ...  WZPX-TV  WZRA-CD  WZRB  WZTV  WZVI  \
# zipcode                             ...
# 00501          0        0        0  ...        0        0     0     0     0
# 00544          0        0        0  ...        0        0     0     0     0
# 00601          0        0        0  ...        0        0     0     0     0
# 00602          0        0        0  ...        0        0     0     0     0
# 00603          0        0        0  ...        0        0     0     0     0
#
#          WZVN-TV  WZXZ-CD  WZZM  k_means_cluster  zipcode
# zipcode
# 00501          0        0     0              134    00501
# 00544          0        0     0              134    00544
# 00601          0        0     0                1    00601
# 00602          0        0     0                1    00602
# 00603          0        0     0                1    00603
#
# [5 rows x 2029 columns]
